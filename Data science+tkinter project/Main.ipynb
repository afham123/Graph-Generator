# %%
from tkinter import*
from PIL import Image
import matplotlib.pyplot as Plt
import seaborn as sns
from PIL import ImageTk,Image
from tkinter import ttk
from tkinter import filedialog
import pandas as pd
from tkinter import messagebox

root=Tk()

login_condition = False

d={}
d["Afham"]="1234"
def login_func():
    global d
    if txt_user.get() == "" or txt_user_password.get() == "":
        messagebox.showerror("Error","All fields are recquired")
    else:
        if d[txt_user.get()] == txt_user_password.get():
            succ_login()
            login_condition = True
                
        else:
            messagebox.showerror("Error","Incorrect Password")
            messagebox.showerror("Error","Incorrect User Id")
def func():   
    if drop.get() == "Select":
        drop1['values']=('select')
        drop1.place(x=20,y=270,width=200)

    elif drop.get() == "Distribution Plot":
        drop1['value']=('Select','Distplot','Jointplot','Pairplot','Rugplot','Kdeplot')
        drop1.place(x=20,y=270,width=200)
        drop1.current(0)

    elif drop.get() == "Categorical Plot":
        drop1['value']=('Select','Factorplot','Boxplot','Violinplot','Stripplot','Swarmplot','Countplot')
        drop1.place(x=20,y=270,width=200)
        drop1.current(0)

    elif drop.get() == "Matrix Plot":
        drop1['value']=('Select','Heat Map')
        drop1.place(x=20,y=270,width=200)
        drop1.current(0)

    else:
        drop1['value']=('Select','lmplot')
        drop1.place(x=20,y=270,width=200)
        drop1.current(0)
        
my_label=Label(root,text='abc')        
def generate():
    global bg1,fig,var,my_label
    global d1,d2,d3,d4,d5,d6
    global str1
    my_label.place_forget()
    if drop1.get() == "Distplot":
        Plt.clf()         
        if d1.get() == "True": v=True
        else: v=False
        if d2.get() == "True" : v1=True
        else : v1=False
        if d3.get() == "None": 
            plt=sns.distplot(tips[d4.get()],kde=v,hist=v1)
        else :
            plt=sns.distplot(tips[d4.get()],kde=v,hist=v1,color=d3.get())
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
    elif drop1.get() == "Jointplot":
        Plt.clf()
        if d3.get() == "None":
            plt=sns.jointplot(x=d1.get(),y=d2.get(),data=tips,kind=d4.get())
        else :
            plt=sns.jointplot(x=d1.get(),y=d2.get(),data=tips,kind=d4.get(),color=d3.get())
        plt.savefig("cache_data/output.png",dpi=78)
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=20,y=0)
        
    elif drop1.get() == 'Pairplot':
        Plt.clf()
        if d1.get() == "None":
            sns_plot = sns.pairplot(tips,hue=d2.get(),kind=d3.get())
        else :
            sns_plot = sns.pairplot(tips,hue=d2.get(),palette=d1.get(),kind=d3.get())
        sns_plot.savefig("cache_data/output.png",dpi=59)
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=0)
        
    elif drop1.get() == 'Rugplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        plt=sns.rugplot(tips[d1.get()],color=d2.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
    
    elif drop1.get() == 'Kdeplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        plt=sns.kdeplot(tips[d1.get()],color=d2.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
        
    elif drop1.get() == 'Factorplot':
        Plt.clf()     
        if d3.get() == "None":
            sns_plot=sns.catplot(x=d1.get(),y=d2.get(),data=tips,kind=d4.get(),ci="sd")
        else :
            sns_plot=sns.catplot(x=d1.get(),y=d2.get(),data=tips,kind=d4.get(),ci="sd",palette=d3.get())
        sns_plot.savefig("cache_data/output.png",dpi=92)
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=0)
        
    
    elif drop1.get() == 'Boxplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        if d3.get() == "None":
            plt=sns.boxplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get())
        else :
            plt=sns.boxplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get(),palette=d3.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
    
    
    elif drop1.get() == 'Violinplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        if d3.get() == "None":
            plt=sns.violinplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get())
        else :
            plt=sns.violinplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get(),palette=d3.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
        
    elif drop1.get() == 'Stripplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        if d3.get() == "None":
            plt=sns.stripplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get())
        else :
            plt=sns.stripplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get(),palette=d3.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
        
    elif drop1.get() == 'Swarmplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        if d3.get() == "None":
            plt=sns.swarmplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get())
        else :
            plt=sns.swarmplot(x=d1.get(), y=d2.get(), data=tips,hue=d4.get(),palette=d3.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
    elif drop1.get() == 'Countplot':
        Plt.clf()
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        if d3.get() == "None":
            plt=sns.countplot(x=d1.get(), data=tips,hue=d4.get())
        else :
            plt=sns.countplot(x=d1.get(), data=tips,hue=d4.get(),palette=d3.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
    elif drop1.get() == 'Heat Map':
        Plt.clf()
        if d1.get() == "True":v=True
        else :v=False
        
        fig = Plt.figure(figsize=(5,3.45), dpi=100)
        if d2.get() == "None":
            plt=sns.heatmap(tips.corr(),annot=v)
        else :
            plt=sns.heatmap(tips.corr(),annot=v,cmap=d2.get())
        fig=plt.get_figure()
        fig.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=0,y=50)
        
        
    elif drop1.get() == 'lmplot':
        Plt.clf()
        fig = Plt.figure(figsize=(4.32,2.88), dpi=100)
        plt=sns.lmplot(x=d1.get(),y=d2.get(),data=tips,ci=None)
        plt.savefig("cache_data/output.png")
        Plt.close(fig)
    
        bg1=ImageTk.PhotoImage(file="cache_data/output.png")
        my_label=Label(graph_frame,image=bg1,bd=0)
        my_label.place(x=34,y=70)   
        
        

def okfunc():
    
    global cat_dtype,non_cat_dtype
    global d1,d2,d3,d4
    global l1,l2,l3,l4
    try :
        d1.place_forget()
        l1.destroy()
    except :
        pass      
    try :
        d2.place_forget()
        l2.destroy()    
    except :
        pass
    try:
        d3.place_forget()
        l3.destroy()
    except :
        pass
    try :
        d4.place_forget()
        l4.destroy()
    except :
        pass
    if drop1.get() == "Distplot":
        l1=Label(root,text="Kde",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #kde dropdownbox
        d1['values']=("True","False")
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Hist",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #hist dropdownbox
        d2['values']=("True","False")
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
        l3=Label(root,text="Color",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","red","black","blue","green")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Column",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')                   #column dropdownbox
        d4['values']=tuple(non_cat_dtype)
        d4.place(x=155,y=480,width=200)
        d4.current(0)     
        
    elif drop1.get() == "Jointplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(non_cat_dtype)
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
        l3=Label(root,text="Color",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","red","black","blue","green")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Kind",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #kind dropdownbox
        d4['values']=("scatter","resid","kde","hex")
        d4.place(x=155,y=480,width=200)
        d4.current(0) 
        
        
        
    elif drop1.get() == "Pairplot":
        l1=Label(root,text="Palatte",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox()   #Palatte dropdownbox
        d1['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Hue",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #hue dropdownbox
        d2['values']=tuple(cat2_dtype)
        d2.place(x=155,y=405,width=200)
        
        l3=Label(root,text="Kind",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox(state='readonly')                   #color dropdownbox
        d3['values']=("scatter","resid","kde","hex")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
    elif drop1.get() == "Rugplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(non_cat_dtype)
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Color",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox()   #color dropdownbox
        d2['values']=("red","black","blue","green")
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
    
    elif drop1.get() == "Kdeplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(non_cat_dtype)
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Color",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox()   #color dropdownbox
        d2['values']=("red","black","blue","green")
        d2.place(x=155,y=405,width=200)
        d2.current(0)  
        
    
    
    elif drop1.get() == "Boxplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(cat_dtype)
        d1.place(x=155,y=370,width=200)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(1)
        
        l3=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Hue",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #hue dropdownbox
        d4['values']=tuple(cat2_dtype)
        d4.place(x=155,y=480,width=200)
        d4.current(0) 
        
    elif drop1.get() == "Stripplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(cat_dtype)
        d1.place(x=155,y=370,width=200)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(1)
        
        l3=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Hue",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #hue dropdownbox
        d4['values']=tuple(cat2_dtype)
        d4.place(x=155,y=480,width=200)
        d4.current(0) 
        
    elif drop1.get() == "Factorplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(cat_dtype)
        d1.place(x=155,y=370,width=200)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
        l3=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Kind",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #hue dropdownbox
        d4['values']=("point","bar","strip","swarm","box","violin","boxen")
        d4.place(x=155,y=480,width=200)
        d4.current(0) 
        
    elif drop1.get() == "Violinplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(cat_dtype)
        d1.place(x=155,y=370,width=200)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
        l3=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Hue",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #hue dropdownbox
        d4['values']=tuple(cat2_dtype)
        d4.place(x=155,y=480,width=200)
        
    elif drop1.get() == "Swarmplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(cat_dtype)
        d1.place(x=155,y=370,width=200)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
        l3=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Hue",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #hue dropdownbox
        d4['values']=tuple(cat2_dtype)
        d4.place(x=155,y=480,width=200)
        
        
    elif drop1.get() == "Countplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(cat_dtype)
        d1.place(x=155,y=370,width=200)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
        l3=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l3.place(x=20,y=440)
        d3=ttk.Combobox()                   #color dropdownbox
        d3['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d3.place(x=155,y=440,width=200)
        d3.current(0)
        
        
        l4=Label(root,text="Hue",bg="#d77337",fg="white",width=14,pady=2.4)
        l4.place(x=20,y=480)
        d4=ttk.Combobox(state='readonly')    #hue dropdownbox
        d4['values']=tuple(cat2_dtype)
        d4.place(x=155,y=480,width=200)
        
    elif drop1.get() == "Heat Map":
        l1=Label(root,text="Annot",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=("True","False")
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Palette",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox()   #y-axis dropdownbox
        d2['values']=("None","coolwarm","twilight_shifted","Pastel1","Pastel2")
        d2.place(x=155,y=405,width=200)
        d2.current(0)
        
    elif drop1.get() == "lmplot":
        l1=Label(root,text=" X Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l1.place(x=20,y=370)
        d1=ttk.Combobox(state='readonly')   #x-axis dropdownbox
        d1['values']=tuple(non_cat_dtype)
        d1.place(x=155,y=370,width=200)
        d1.current(0)
        
        l2=Label(root,text="Y Axis",bg="#d77337",fg="white",width=14,pady=2.4)
        l2.place(x=20,y=405)
        d2=ttk.Combobox(state='readonly')   #y-axis dropdownbox
        d2['values']=tuple(non_cat_dtype)
        d2.place(x=155,y=405,width=200)
        d2.current(0)
    
def savefunc():
    image = Image.open("cache_data/output.png")
    file= filedialog.asksaveasfile(mode='w', defaultextension=".png")  
    image.show()
    if file:
        image.save(file.name)
        
    
def clear_bttn_func():
    try :
        d1.place_forget()
        l1.destroy()
    except :
        pass      
    try :
        d2.place_forget()
        l2.destroy()    
    except :
        pass
    try:
        d3.place_forget()
        l3.destroy()
    except :
        pass
    try :
        d4.place_forget()
        l4.destroy()
    except :
        pass


def succ_login():
    global drop1,exit_bttn,my_label1,bg,drop_get_button,drop,tips,cat_dtype,non_cat_dtype,cat2_dtype,graph_frame,save_bttn
    root.geometry("980x630+70+65")
    root.title("Get Graphs")
    root.resizable(False,False)
    bg=ImageTk.PhotoImage(file="Image/image.jpg")
    my_label1=Label(root,image=bg)
    my_label1.pack()
    
    l23=Label(root,text="  GRAPH   GENERATOR  ",bg="#d77337",fg="white",font=("Impact",27,"bold")).place(x=325,y=30)
    graph_frame=Frame(root,bg="white")
    graph_frame.place(x=465,y=165,height=450,width=500)

    root.filename=filedialog.askopenfilename(initialdir="C:/Users/Afhamfardeen98/Desktop/Python material/Thinter/Data science+tkinter project",
                                             title="Select a file",filetypes=(("all file","*.*"),("exel file","*.xlsx")))

    
    if root.filename.split('.')[-1] == 'xlsx':
        tips=pd.read_excel(root.filename)

    elif root.filename.split('.')[-1] == 'csv':
        tips=pd.read_csv(root.filename)

    i=0
    cat_dtype=[]
    non_cat_dtype=[]
    cat2_dtype=[]
    for col in tips:
        if tips[col].nunique() == 2:
            cat2_dtype.append(col)
        elif tips[col].nunique() <= 10:
            cat_dtype.append(col)    
        else:
            non_cat_dtype.append(col)
        i+=1




    l89=Label(root,text="Graph Type",bg="#d77337",fg="white",width=10)
    l89.place(x=20,y=175)
    drop=ttk.Combobox(state='readonly')
    drop['values']=("Select","Distribution Plot","Categorical Plot","Matrix Plot","Regression Plot")
    drop.place(x=20,y=200,width=200)
    drop.current(0)
    
    drop_get_button=Button(root,text="Ok",bg="#d77337",fg="white",command=func)
    drop_get_button.place(x=270,y=200,width=100,height=25)

    ok_func_bttn=Button(root,text="Ok",bg="#d77337",fg="white",command=okfunc)
    ok_func_bttn.place(x=270,y=270,width=100,height=25)

    l2=Label(root,text="Graph",bg="#d77337",fg="white",width=10).place(x=20,y=245)
    drop1=ttk.Combobox(state='readonly')
    drop1.place(x=20,y=270,width=200)


    save_bttn=Button(root,text="Save",bg="#d77337",fg="white",command=savefunc)
    save_bttn.place(x=20,y=580,width=75,height=25)

    clear_bttn=Button(root,text="Clear",bg="#d77337",fg="white",command=clear_bttn_func)
    clear_bttn.place(x=120,y=580,width=75,height=25)

    generate_bttn=Button(root,text="Generate",bg="#d77337",fg="white",command=generate)
    generate_bttn.place(x=220,y=580,width=75,height=25)

    exit_bttn=Button(root,text="Exit",bg="#d77337",fg="white",command=root.destroy)
    exit_bttn.place(x=320,y=580,width=75,height=25)

    
root.title("Login System")
root.geometry("1093x652+70+65")
root.resizable(False,False)
        
        # backgroung image
bg=ImageTk.PhotoImage(file="image/image1.jpg")
bg_image=Label(image=bg).place(x=0,y=0,relwidth=1,relheight=1)
        
        #login frame
login_frame=Frame(root,bg="white")
login_frame.place(x=80,y=230,height=350,width=300)
        
Label(login_frame,text="Login Here",font=("Impact",35,"bold"),fg="#d77337",bg="white").place(x=40,y=20)
        
Label(login_frame,text="Accountant Employee Login Area",font=("Goudy old style",13,"bold"),fg="#d25d17",bg="white").place(x=26,y=87)
Label(login_frame,text="User name",font=("Goudy old style",13,"bold"),fg="grey",bg="white").place(x=26,y=120)
txt_user=Entry(login_frame,font=("times new roman",13),bg="lightgray",width=24)
txt_user.place(x=26,y=145)
    
Label(login_frame,text="Password",font=("Goudy old style",13,"bold"),fg="grey",bg="white").place(x=26,y=175)
txt_user_password=Entry(login_frame,font=("times new roman",13),bg="lightgray",width=24)
txt_user_password.place(x=26,y=200)
        
Button(login_frame,text="Forget Password?",bg="white",fg="#d77337",bd=0,cursor="hand2",font=("times new roman",12,"bold")).place(x=26,y=225)
Button(login_frame,text="Login",bg="#d77337",fg="white",cursor="hand2",font=("times new roman",18),command=login_func).place(x=26,y=270,width=180,height=40)

root.mainloop()

# %%
Available Palletes : "Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r"
# Out:
#   File "<ipython-input-10-126392941afb>", line 1
# ...
